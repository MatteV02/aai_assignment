# %%
# PSP System with RL Agent
# %pip install simpy numpy matplotlib scipy stable_baselines3 torch gym tensorboard standard-imghdr
# %load_ext tensorboard
import simpy
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.vec_env import VecNormalize
from gym import spaces
import gym

# Simulation parameters
SIM_TIME = 20_000
WARM_UP = 2_000
WC_IDS = [1, 2, 3, 4, 5, 6]
FAMILY_PROBS = {1: 0.10, 2: 0.52, 3: 0.38}
PROCESSING_PARAMS = {1: (2, 2), 2: (4, 0.5), 3: (6, 1/6)}
ROUTING = {
    1: {1: 1.0, 2: 1.0, 4: 1.0, 5: 1.0, 6: 1.0},
    2: {1: 0.8, 2: 0.8, 3: 1.0, 4: 0.8, 5: 0.8, 6: 0.75},
    3: {3: 1.0, 6: 0.75}
}
ARRIVAL_RATE = 0.65
DUE_TIME = (30, 50)
DECISION_INTERVAL = ARRIVAL_RATE/2
TARGET_THROUGHPUT = 0.65  # PUSH system's throughput

class Job:
    next_id = 1
    
    def __init__(self, env, family):
        self.jid = Job.next_id
        Job.next_id += 1
        self.family = family
        self.arrival_time = env.now
        self.due_date = self.arrival_time + random.uniform(DUE_TIME[0], DUE_TIME[1])
        self.completion_time : None | float = None
        self.release_time = None
        
        # Precompute routing and workload
        self.routing = {}
        self.remaining_workload = 0.0
        for wc_id, prob in ROUTING[family].items():
            if random.random() < prob:
                alpha, beta = PROCESSING_PARAMS[family]
                processing_time = random.gammavariate(alpha, beta)
                self.routing[wc_id] = processing_time
                self.remaining_workload += processing_time

    def __repr__(self):
        return f"Job {self.jid} (F{self.family}) due @ {self.due_date:.2f} workload={self.remaining_workload:.2f}"
# Out:
# Requirement already satisfied: simpy in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (4.1.1)
# Requirement already satisfied: numpy in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (2.2.4)
# Requirement already satisfied: matplotlib in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (3.10.1)
# Requirement already satisfied: scipy in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (1.15.2)
# Requirement already satisfied: stable_baselines3 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (2.6.0)
# Requirement already satisfied: torch in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (2.6.0+cu126)
# Requirement already satisfied: gym in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (0.26.2)
# Requirement already satisfied: tensorboard in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (2.19.0)
# Requirement already satisfied: standard-imghdr in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (3.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from stable_baselines3) (1.1.1)
# Requirement already satisfied: cloudpickle in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from stable_baselines3) (2.3.0)
# Requirement already satisfied: filelock in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (4.14.0)
# Requirement already satisfied: setuptools in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (78.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (12.6.85)
# Requirement already satisfied: triton==3.2.0 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from torch) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: gym_notices>=0.0.4 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from gym) (0.0.8)
# Requirement already satisfied: absl-py>=0.4 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from tensorboard) (2.3.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from tensorboard) (1.73.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from tensorboard) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from tensorboard) (6.31.1)
# Requirement already satisfied: six>1.9 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages (from pandas->stable_baselines3) (2025.2)
# Note: you may need to restart the kernel to use updated packages.
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
from collections import defaultdict


class ManufacturingEnv(gym.Env):
    def __init__(self):
        super(ManufacturingEnv, self).__init__()
        self.observation_space = spaces.Box(
            low=0, 
            high=np.inf,
            shape=(24,), 
            dtype=np.float32
        )
        self.action_space = spaces.Discrete(2)  # 0=hold, 1=release one
        self.env: simpy.Environment
        self.psp = deque()
        self.wcs: dict[int, simpy.Resource]
        self.stats: dict
        self.gamma = 0.99
        self.decision_interval = DECISION_INTERVAL
        self.wc_queues = {wc_id: [] for wc_id in WC_IDS}
        self.job_arrival_event: simpy.Event
        self.reset()
        
    def reset_stats(self):
        self.stats = {
            'generated': 0,
            'completed_jobs': [],
            'active_jobs_time_at_level': defaultdict(float),
            'last_active_jobs_update_time': 0.0,
            'last_active_jobs_count': 0,
            'total_remaining_workload': 0.0,
            'workload_events': [],  # (time, workload) tuples
            'flow_times' : [], # (completion_time, flow time)
            'wc_busy_time': {wc: 0 for wc in WC_IDS},
            'queue_times': {wc: [] for wc in WC_IDS},
            'tardiness': [],
            'earliness': [],
            'tardiness_over_time': [],   # (completion_time, tardiness)
            'earliness_over_time': [],    # (completion_time, earliness)
            'family_counts': {1: 0, 2: 0, 3: 0},
            'family_tardiness': {1: [], 2: [], 3: []},
            'family_earliness': {1: [], 2: [], 3: []},
            'arrival_times': {1: [], 2: [], 3: []},
            'released_jobs': 0
        }
    
    def reset(self):
        self.env = simpy.Environment()
        self.job_arrival_event = self.env.event()
        self.psp = deque()
        self.wcs = {wc_id: simpy.Resource(self.env) for wc_id in WC_IDS}
        self.wc_queues = {wc_id: [] for wc_id in WC_IDS}
        self.reset_stats()
        Job.next_id = 1
        self.active_jobs=[]
        
        self.env.process(self.job_generator())
        return self._get_state()
    
    def _get_state(self):
        """Build state vector"""
        # state = np.zeros(18, dtype=np.float32)
        state = np.zeros(24, dtype=np.float32)
        
        # 1. Queue lengths at each WC (indices 0-5)
        for i, wc_id in enumerate(WC_IDS):
            state[i] = len(self.wcs[wc_id].queue)
        
        # 2. Workload at each WC (indices 6-11)
        for i, wc_id in enumerate(WC_IDS):
            total_workload = 0
            for job in self.wc_queues[wc_id]:
                total_workload += job.routing[wc_id]
            state[6 + i] = total_workload
        
        # 3. PSP count (index 12)
        state[12] = len(self.psp)
        
        if self.psp:
            # Get most urgent job
            job = min(self.psp, key=lambda j: j.due_date)
            
            # 4. One-hot family encoding (indices 13-15)
            state[13 + job.family - 1] = 1
            
            # 5. Due date remaining (index 16)
            state[16] = job.due_date - self.env.now
            
            # 6. Wait time (index 17)
            state[17] = self.env.now - job.arrival_time
        
            # 7. processing time at each WC (indices 18-23)
            for wc_id, processing_time in job.routing.items():
                state[18 + wc_id - 1] = processing_time

        return state
    
    def _release_job(self):
        job = min(self.psp, key=lambda j: j.due_date)
        self.psp.remove(job)
        job.release_time = self.env.now  # Track release time
        self.env.process(self.process_job(job))
        self.stats['released_jobs'] += 1
    
    def step(self, action):
        if action == 1 and self.psp:
            self._release_job()
        
        start_time = self.env.now
        self.env.run(until=self.job_arrival_event)
        
        reward = self._calculate_reward()
        next_state = self._get_state()
        done = self.env.now >= SIM_TIME
        info = {}
        
        return next_state, reward, done, info
    
    def _calculate_reward(self):
        """Penalize flow time of uncompleted jobs (do not consider the job you just released)"""
        uncompleted_jobs_throughputs = [self.env.now - j.arrival_time for j in self.active_jobs if j.arrival_time != self.env.now]
        if uncompleted_jobs_throughputs:
            return - np.sum(uncompleted_jobs_throughputs)
        else:
            return 0.0

    
    def job_generator(self):
        while True:
            family = random.choices([1, 2, 3], weights=list(FAMILY_PROBS.values()))[0]
            job = Job(self.env, family)
            self.psp.append(job)
            self.active_jobs.append(job)
            self.stats['generated'] += 1
            self.stats['family_counts'][family] += 1
            self.stats['arrival_times'][family].append(self.env.now)
            
            self.job_arrival_event.succeed()
            self.job_arrival_event = self.env.event()
            
            interarrival = random.expovariate(ARRIVAL_RATE)
            yield self.env.timeout(interarrival)
    
    def process_job(self, job: Job):
        time_spent = self.env.now - self.stats['last_active_jobs_update_time']
        self.stats['active_jobs_time_at_level'][self.stats['last_active_jobs_count']] += time_spent
        self.stats['last_active_jobs_update_time'] = self.env.now
        self.stats['last_active_jobs_count'] += 1  # Job enters system

        self.stats['total_remaining_workload'] += job.remaining_workload
        self.stats['workload_events'].append((self.env.now, self.stats['total_remaining_workload']))
        
        for wc_id, processing_time in job.routing.items():
            wc = self.wcs[wc_id]
            with wc.request() as req:
                self.wc_queues[wc_id].append(job)
                queue_start = self.env.now
                yield req
                self.wc_queues[wc_id].remove(job)
                
                queue_time = self.env.now - queue_start
                self.stats['queue_times'][wc_id].append(queue_time)

                self.stats['total_remaining_workload'] -= processing_time
                job.remaining_workload -= processing_time
                self.stats['workload_events'].append((self.env.now, self.stats['total_remaining_workload']))
                
                yield self.env.timeout(processing_time)

                self.stats['wc_busy_time'][wc_id] += processing_time
        
        # Job completion
        job.completion_time = self.env.now
        self.stats['completed_jobs'].append(job)
        if self.env.now > WARM_UP:
            time_spent = self.env.now - self.stats['last_active_jobs_update_time']
            self.stats['active_jobs_time_at_level'][self.stats['last_active_jobs_count']] += time_spent
        self.stats['last_active_jobs_update_time'] = self.env.now
        self.stats['last_active_jobs_count'] -= 1  # Job leaves system

        self.stats['flow_times'].append((self.env.now, job.completion_time - job.arrival_time))
        
        tardiness = max(0, job.completion_time - job.due_date)
        earliness = max(0, job.due_date - job.completion_time)

        self.active_jobs.remove(job)
        
        if self.env.now > WARM_UP:
            self.stats['tardiness'].append(tardiness)
            self.stats['earliness'].append(earliness)
            self.stats['tardiness_over_time'].append((self.env.now, tardiness))
            self.stats['earliness_over_time'].append((self.env.now, earliness))
            self.stats['family_tardiness'][job.family].append(tardiness)
            self.stats['family_earliness'][job.family].append(earliness)
        
    def get_kpis(self):
        """Compute KPIs from simulation statistics"""
        # Average active_jobs
        total_time = SIM_TIME - WARM_UP
        
        # Filter active job data to post-warm-up period
        active_jobs_time = self.stats['active_jobs_time_at_level']
        
        weighted_sum = sum(
            level * duration 
            for level, duration in active_jobs_time.items()
        )

        # Calculate average total remaining workload
        events = sorted(self.stats['workload_events'], key=lambda x: x[0])
        total_time = self.env.now
        integral = 0.0
        
        if events:
            # Handle warm-up period
            start_index = 0
            prev_workload = 0
            for i, (time, workload) in enumerate(events):
                if time > WARM_UP:
                    start_index = i
                    break
                prev_workload = workload
            
            # Calculate integral from WARM_UP to end
            if start_index > 0:
                integral += prev_workload * (events[start_index][0] - WARM_UP)
            
            for i in range(start_index, len(events)-1):
                t1, w1 = events[i]
                t2, w2 = events[i+1]
                integral += w1 * (t2 - t1)
            
            if events and events[-1][0] < total_time:
                integral += events[-1][1] * (total_time - events[-1][0])
        
        avg_workload = integral / max(1, total_time - WARM_UP)
        
        avg_jobs_in_system = weighted_sum / total_time if total_time > 0 else 0
        
        # Tardiness/Earliness/Flow Time
        avg_tardiness = np.mean(self.stats['tardiness']) if self.stats['tardiness'] else 0
        avg_earliness = np.mean(self.stats['earliness']) if self.stats['earliness'] else 0
        
        avg_flow_times = np.mean([flow_time for timestamp, flow_time in self.stats['flow_times'] if timestamp > WARM_UP])
        
        # Throughput
        elapsed_time = max(1, self.env.now - WARM_UP)
        completed_after_warmup = [j for j in self.stats['completed_jobs'] if j.completion_time > WARM_UP]
        throughput = len(completed_after_warmup) / elapsed_time
        
        # Utilization
        utilizations = {wc: self.stats['wc_busy_time'][wc] / max(1, self.env.now) for wc in WC_IDS}
        
        return {
            'Average jobs in system (L)': avg_jobs_in_system,
            'Average Total Remaining Workload': avg_workload,
            'Average Tardiness': avg_tardiness,
            'Average Earliness': avg_earliness,
            'Average Flow Times': avg_flow_times,
            'Throughput': throughput,
            'WC Utilization': utilizations,
            'Jobs Released': self.stats['released_jobs'],
            'Jobs Completed': len(self.stats['completed_jobs'])
        }

# %%
# Create environment
env = SubprocVecEnv([lambda: ManufacturingEnv() for _ in range(16)])
env = VecNormalize(env, norm_obs=True, norm_reward=True)

final_model = PPO("MlpPolicy", env, batch_size=128, verbose=1, tensorboard_log="./rl_agent_tensorboard/", device='cpu') # PPO_30
final_model.learn(total_timesteps=1_200_000)

# Save model
final_model.save("optimized_production_agent")
env.save("optimized_vec_normalize.pkl")

print("\nFinal model trained and saved!")

# %%
# Visualize the learned policy
def visualize_policy(episode_duration=500):
    # Load environment and model
    eval_env = VecNormalize.load("optimized_vec_normalize.pkl", DummyVecEnv([lambda: ManufacturingEnv()]))
    eval_env.training = False
    model = PPO.load("optimized_production_agent", env=eval_env, device='cpu')
    
    # Create environment instance
    env = ManufacturingEnv()
    state = env.reset()
    done = False
    
    # Data collection structures
    decision_points = []
    psp_sizes = []
    due_dates = []
    actions = []
    job_arrivals = []
    releases = []
    
    print("\nRunning policy visualization...")
    while not done and env.env.now < episode_duration:
        # Record pre-decision state
        current_time = env.env.now
        psp_size = len(env.psp)
        urgent_due = min(j.due_date for j in env.psp) if env.psp else 0
        
        # Get agent action
        action, _ = model.predict(state, deterministic=True)
        
        # Execute action
        next_state, _, done, _ = env.step(action)
        state = next_state
        
        # Record data
        decision_points.append(current_time)
        psp_sizes.append(psp_size)
        due_dates.append(urgent_due - current_time if urgent_due else 0)
        actions.append(action)
        
        # Track new arrivals and releases
        if env.stats['arrival_times']:
            for family, times in env.stats['arrival_times'].items():
                for t in times:
                    if t > current_time and t <= env.env.now:
                        job_arrivals.append((t, family))
        
        if action == 1 and env.psp:
            releases.append((env.env.now, min(env.psp, key=lambda j: j.due_date).jid))

    # Visualization
    plt.figure(figsize=(15, 10))
    
    # PSP size and decisions
    plt.subplot(3, 1, 1)
    plt.step(decision_points, psp_sizes, where='post', label='PSP Size')
    plt.xlabel('Simulation Time')
    plt.ylabel('Jobs in PSP')
    plt.title('PSP Inventory and Agent Decisions')
    
    # Mark decision points
    for i, (t, action) in enumerate(zip(decision_points, actions)):
        color = 'green' if action == 1 else 'red'
        plt.axvline(t, color=color, alpha=0.3, linestyle='--')
    
    # Mark job arrivals
    for t, family in job_arrivals:
        plt.axvline(t, color='blue', alpha=0.5, linestyle=':')
        plt.text(t, max(psp_sizes)*1.05, f'F{family}', rotation=90, 
                 verticalalignment='top', fontsize=8)
    
    # Mark releases
    release_times = [t for t, _ in releases]
    release_jids = [jid for _, jid in releases]
    plt.scatter(release_times, [0]*len(release_times), color='green', 
                marker='^', s=100, label='Job Release')
    
    for t, jid in releases:
        plt.text(t, -0.5, f'J{jid}', rotation=90, 
                 verticalalignment='top', fontsize=8)
    
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Due date urgency
    plt.subplot(3, 1, 2)
    plt.step(decision_points, due_dates, where='post', color='orange')
    plt.xlabel('Simulation Time')
    plt.ylabel('Due Date Remaining')
    plt.title('Most Urgent Job in PSP (Due Date - Current Time)')
    plt.grid(True, alpha=0.3)
    
    # Action types
    plt.subplot(3, 1, 3)
    plt.step(decision_points, actions, where='post')
    plt.yticks([0, 1], ['Hold', 'Release'])
    plt.xlabel('Simulation Time')
    plt.ylabel('Agent Action')
    plt.title('Agent Decision at Each Time Step')
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Print decision log
    print("\nDecision Log (First 20 decisions):")
    print(f"{'Time':<10}{'PSP Size':<10}{'Due Remaining':<15}{'Action':<10}")
    for i in range(min(20, len(decision_points))):
        t = decision_points[i]
        size = psp_sizes[i]
        due_rem = f"{due_dates[i]:.2f}" if due_dates[i] else "N/A"
        action = "RELEASE" if actions[i] == 1 else "HOLD"
        print(f"{t:<10.2f}{size:<10}{due_rem:<15}{action:<10}")

# Run visualization
visualize_policy(episode_duration=200)
# Out:
# /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Running policy visualization...
# Decision Log (First 20 decisions):
# Time      PSP Size  Due Remaining  Action
# 0.00      0         N/A            RELEASE
# 0.00      1         46.57          HOLD
# 0.58      2         45.99          HOLD
# 3.19      3         32.27          HOLD
# 4.26      4         31.20          HOLD
# 6.80      5         28.66          HOLD
# 7.45      6         28.01          HOLD
# 8.58      7         26.88          HOLD
# 13.00     8         22.47          RELEASE
# 14.92     8         22.30          RELEASE
# 17.97     8         27.87          RELEASE
# 18.88     8         27.69          RELEASE
# 19.61     8         28.79          RELEASE
# 19.72     8         29.19          RELEASE
# 20.92     8         30.35          RELEASE
# 28.05     8         24.46          RELEASE
# 33.42     8         20.26          HOLD
# 34.05     9         19.63          RELEASE
# 36.12     9         20.43          RELEASE
# 39.47     9         18.38          RELEASE

# %%
# Evaluate Optimized Agent
from stable_baselines3.common.vec_env import VecNormalize

def evaluate_optimized_agent(num_episodes: int):
    # Load environment stats
    eval_env = DummyVecEnv([lambda: ManufacturingEnv()])
    eval_env = VecNormalize.load("optimized_vec_normalize.pkl", eval_env)
    eval_env.training = False
    eval_env.norm_reward = False

    # Load model
    model = PPO.load("optimized_production_agent", env=eval_env, device='cpu')
    
    results = []
    
    for i in range(num_episodes):
        random.seed(42 + i)

        print(f"Running evaluation episode {i+1}/5")
        env = ManufacturingEnv()
        state = env.reset()
        done = False
        
        while not done:
            action, _ = model.predict(state, deterministic=True)
            state, _, done, _ = env.step(action)
        
        kpis = env.get_kpis()
        results.append(kpis)
        
        print(f"Episode {i+1} Results:")
        for k, v in kpis.items():
            if isinstance(v, dict):
                print(f"  {k}:")
                for subk, subv in v.items():
                    print(f"    {subk}: {subv:.4f}")
            else:
                print(f"  {k}: {v:.4f}")
    
    return results

# Run evaluation
optimized_results = evaluate_optimized_agent(num_episodes=5)
# Out:
# /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Running evaluation episode 1/5
# Episode 1 Results:
#   Average jobs in system (L): 28.5988
#   Average Total Remaining Workload: 132.8175
#   Average Tardiness: 133.4882
#   Average Earliness: 0.0000
#   Average Flow Times: 173.5598
#   Throughput: 0.6460
#   WC Utilization:
#     1: 0.7884
#     2: 0.7951
#     3: 0.9200
#     4: 0.7910
#     5: 0.7892
#     6: 0.9478
#   Jobs Released: 12915.0000
#   Jobs Completed: 12909.0000
# Running evaluation episode 2/5
# Episode 2 Results:
#   Average jobs in system (L): 25.5746
#   Average Total Remaining Workload: 126.5537
#   Average Tardiness: 121.5429
#   Average Earliness: 0.0000
#   Average Flow Times: 161.5578
#   Throughput: 0.6414
#   WC Utilization:
#     1: 0.7990
#     2: 0.7985
#     3: 0.9009
#     4: 0.7928
#     5: 0.7808
#     6: 0.9416
#   Jobs Released: 12792.0000
#   Jobs Completed: 12761.0000
# Running evaluation episode 3/5
# Episode 3 Results:
#   Average jobs in system (L): 23.5569
#   Average Total Remaining Workload: 120.8164
#   Average Tardiness: 105.5474
#   Average Earliness: 0.0000
#   Average Flow Times: 145.5532
#   Throughput: 0.6387
#   WC Utilization:
#     1: 0.7827
#     2: 0.7875
#     3: 0.9042
#     4: 0.7751
#     5: 0.7733
#     6: 0.9274
#   Jobs Released: 12762.0000
#   Jobs Completed: 12749.0000
# Running evaluation episode 4/5
# Episode 4 Results:
#   Average jobs in system (L): 33.7163
#   Average Total Remaining Workload: 158.8523
#   Average Tardiness: 145.6892
#   Average Earliness: 0.0000
#   Average Flow Times: 185.6884
#   Throughput: 0.6450
#   WC Utilization:
#     1: 0.8000
#     2: 0.7882
#     3: 0.9187
#     4: 0.8104
#     5: 0.8025
#     6: 0.9484
#   Jobs Released: 12876.0000
#   Jobs Completed: 12845.0000
# Running evaluation episode 5/5
# Episode 5 Results:
#   Average jobs in system (L): 30.6660
#   Average Total Remaining Workload: 143.7538
#   Average Tardiness: 152.4125
#   Average Earliness: 0.0000
#   Average Flow Times: 192.4412
#   Throughput: 0.6462
#   WC Utilization:
#     1: 0.7883
#     2: 0.7933
#     3: 0.9119
#     4: 0.8077
#     5: 0.7850
#     6: 0.9470
#   Jobs Released: 12855.0000
#   Jobs Completed: 12850.0000

# %%
# Compare with PUSH System
def run_push_simulation(num_episodes=5):
    """Run the original PUSH system for comparison"""
    results = []
    
    for i in range(num_episodes):
        random.seed(42 + i)
        print(f"Running PUSH simulation {i+1}/{num_episodes}")
        
        env = simpy.Environment()
        wcs = {wc_id: simpy.Resource(env) for wc_id in WC_IDS}
        stats = {
            'generated': 0,
            'completed_jobs': [],
            'active_jobs_time_at_level': defaultdict(float),
            'last_active_jobs_update_time': 0.0,
            'last_active_jobs_count': 0,
            'total_remaining_workload': 0.0,
            'workload_events': [],  # (time, workload) tuples
            'wc_busy_time': {wc: 0 for wc in WC_IDS},
            'queue_times': {wc: [] for wc in WC_IDS},
            'tardiness': [],
            'earliness': [],
            'flow_times': [],
            'family_counts': {1: 0, 2: 0, 3: 0},
            'arrival_times': {1: [], 2: [], 3: []}
        }
        
        env.process(job_generator(env, wcs, stats))
        env.run(until=SIM_TIME)
        
        # Compute KPIs
        # Average active_jobs
        total_time = SIM_TIME - WARM_UP
        
        # Filter active job data to post-warm-up period
        active_jobs_time = stats['active_jobs_time_at_level']
        
        weighted_sum = sum(
            level * duration 
            for level, duration in active_jobs_time.items()
        )
        
        avg_jobs_in_system = weighted_sum / total_time if total_time > 0 else 0

        # Compute average total remaining workload
        events = sorted(stats['workload_events'], key=lambda x: x[0])
        integral = 0.0
        prev_time = 0
        prev_workload = 0
        
        for time, workload in events:
            if time > WARM_UP:
                integral += prev_workload * (time - max(prev_time, WARM_UP))
            prev_time = time
            prev_workload = workload
        
        if prev_time < SIM_TIME:
            integral += prev_workload * (SIM_TIME - max(prev_time, WARM_UP))
        
        total_time = SIM_TIME - WARM_UP
        avg_workload = integral / total_time if total_time > 0 else 0
        
        avg_tardiness = np.mean(stats['tardiness']) if stats['tardiness'] else 0
        avg_earliness = np.mean(stats['earliness']) if stats['earliness'] else 0
        
        avg_flow_time = np.mean([flow_time for timestamp, flow_time in stats['flow_times'] if timestamp > WARM_UP])
        
        elapsed_time = SIM_TIME - WARM_UP
        completed_after_warmup = [j for j in stats['completed_jobs'] if j.completion_time > WARM_UP]
        throughput = len(completed_after_warmup) / elapsed_time
        
        utilizations = {wc: stats['wc_busy_time'][wc] / SIM_TIME for wc in WC_IDS}
        
        kpis = {
            'Average jobs in system (L)': avg_jobs_in_system,
            'Average Total Remaining Workload': avg_workload,
            'Average Tardiness': avg_tardiness,
            'Average Earliness': avg_earliness,
            'Average Flow Times': avg_flow_time,
            'Throughput': throughput,
            'WC Utilization': utilizations,
            'Jobs Released': stats['generated'],
            'Jobs Completed': len(stats['completed_jobs'])
        }
        
        results.append(kpis)
        
        print(f"PUSH Episode {i+1} Results:")
        for k, v in kpis.items():
            if isinstance(v, dict):
                print(f"  {k}:")
                for subk, subv in v.items():
                    print(f"    {subk}: {subv:.4f}")
            else:
                print(f"  {k}: {v:.4f}")
    
    return results

def job_generator(env, wcs, stats):
    while True:
        family = random.choices([1, 2, 3], weights=list(FAMILY_PROBS.values()))[0]
        job = Job(env, family)
        job.release_time = job.arrival_time  # Immediate release in PUSH
        env.process(run_job(env, wcs, stats, job))
        interarrival = random.expovariate(ARRIVAL_RATE)
        yield env.timeout(interarrival)

def run_job(env, wcs, stats, job):
    stats['generated'] += 1
    if env.now > WARM_UP:
        time_spent = env.now - stats['last_active_jobs_update_time']
        stats['active_jobs_time_at_level'][stats['last_active_jobs_count']] += time_spent
    stats['last_active_jobs_update_time'] = env.now
    stats['last_active_jobs_count'] += 1  # Job enters system
    stats['family_counts'][job.family] += 1
    stats['arrival_times'][job.family].append(env.now)

    # Update workload stats
    stats['total_remaining_workload'] += job.remaining_workload
    stats['workload_events'].append((env.now, stats['total_remaining_workload']))

    for wc_id, processing_time in job.routing.items():
        wc = wcs[wc_id]
        with wc.request() as req:
            queue_start = env.now
            yield req
            queue_time = env.now - queue_start
            stats['queue_times'][wc_id].append(queue_time)
            
            stats['total_remaining_workload'] -= processing_time
            job.remaining_workload -= processing_time
            stats['workload_events'].append((env.now, stats['total_remaining_workload']))

            yield env.timeout(processing_time)
            stats['wc_busy_time'][wc_id] += processing_time

    job.completion_time = env.now
    flow_time = job.completion_time - job.arrival_time
    stats['completed_jobs'].append(job)
    if env.now > WARM_UP:
        time_spent = env.now - stats['last_active_jobs_update_time']
        stats['active_jobs_time_at_level'][stats['last_active_jobs_count']] += time_spent
    stats['last_active_jobs_update_time'] = env.now
    stats['last_active_jobs_count'] -= 1  # Job leaves system
    
    stats['flow_times'].append((env.now, flow_time))
    
    tardiness = max(0, job.completion_time - job.due_date)
    earliness = max(0, job.due_date - job.completion_time)
    
    if env.now > WARM_UP:
        stats['tardiness'].append(tardiness)
        stats['earliness'].append(earliness)

# Run comparisons
push_results = run_push_simulation(num_episodes=5)
# Out:
# Running PUSH simulation 1/5
# PUSH Episode 1 Results:
#   Average jobs in system (L): 32.4250
#   Average Total Remaining Workload: 141.6323
#   Average Tardiness: 18.0716
#   Average Earliness: 7.8968
#   Average Flow Times: 50.2374
#   Throughput: 0.6472
#   WC Utilization:
#     1: 0.7952
#     2: 0.8013
#     3: 0.9261
#     4: 0.7968
#     5: 0.7956
#     6: 0.9547
#   Jobs Released: 13010.0000
#   Jobs Completed: 12990.0000
# Running PUSH simulation 2/5
# PUSH Episode 2 Results:
#   Average jobs in system (L): 28.8044
#   Average Total Remaining Workload: 135.3119
#   Average Tardiness: 14.7704
#   Average Earliness: 10.0527
#   Average Flow Times: 44.7278
#   Throughput: 0.6427
#   WC Utilization:
#     1: 0.8052
#     2: 0.8038
#     3: 0.9077
#     4: 0.7988
#     5: 0.7871
#     6: 0.9485
#   Jobs Released: 12883.0000
#   Jobs Completed: 12845.0000
# Running PUSH simulation 3/5
# PUSH Episode 3 Results:
#   Average jobs in system (L): 25.4778
#   Average Total Remaining Workload: 121.7984
#   Average Tardiness: 10.0553
#   Average Earliness: 10.1699
#   Average Flow Times: 39.8909
#   Throughput: 0.6396
#   WC Utilization:
#     1: 0.7872
#     2: 0.7938
#     3: 0.9100
#     4: 0.7807
#     5: 0.7781
#     6: 0.9326
#   Jobs Released: 12845.0000
#   Jobs Completed: 12819.0000
# Running PUSH simulation 4/5
# PUSH Episode 4 Results:
#   Average jobs in system (L): 38.3498
#   Average Total Remaining Workload: 159.1201
#   Average Tardiness: 27.1831
#   Average Earliness: 7.7814
#   Average Flow Times: 59.3983
#   Throughput: 0.6484
#   WC Utilization:
#     1: 0.8054
#     2: 0.7933
#     3: 0.9254
#     4: 0.8156
#     5: 0.8084
#     6: 0.9553
#   Jobs Released: 12967.0000
#   Jobs Completed: 12944.0000
# Running PUSH simulation 5/5
# PUSH Episode 5 Results:
#   Average jobs in system (L): 37.0028
#   Average Total Remaining Workload: 156.3939
#   Average Tardiness: 25.3455
#   Average Earliness: 8.2278
#   Average Flow Times: 57.1530
#   Throughput: 0.6477
#   WC Utilization:
#     1: 0.7954
#     2: 0.7986
#     3: 0.9194
#     4: 0.8131
#     5: 0.7917
#     6: 0.9526
#   Jobs Released: 12956.0000
#   Jobs Completed: 12946.0000

# %%
# Visualization
def compare_results(push_results, rl_results):
    metrics = ['Average jobs in system (L)', 'Average Total Remaining Workload', 'Average Tardiness', 'Throughput', 'Jobs Completed', 'Average Flow Times']
    
    push_means = {m: np.mean([r[m] for r in push_results]) for m in metrics}
    rl_means = {m: np.mean([r[m] for r in rl_results]) for m in metrics}
    
    improvements = {}
    for m in metrics:
        if push_means[m] != 0:
            improvement = (push_means[m] - rl_means[m]) / push_means[m] * 100
        else:
            improvement = 0
        improvements[m] = improvement

    improvements['Throughput'] *= -1
    improvements['Jobs Completed'] *= -1
    
    # Plot comparison
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    x = np.arange(len(metrics))
    width = 0.35
    
    plt.bar(x - width/2, [push_means[m] for m in metrics], width, label='PUSH')
    plt.bar(x + width/2, [rl_means[m] for m in metrics], width, label='RL')
    
    plt.ylabel('Value')
    plt.title('Performance Comparison: PUSH vs Optimized RL')
    plt.xticks(x, metrics)
    plt.legend()
    
    plt.subplot(2, 1, 2)
    colors = ['green' if i > 0 else 'red' for i in improvements.values()]
    plt.bar(metrics, list(improvements.values()), color=colors)
    plt.axhline(0, color='black', linewidth=0.8)
    plt.ylabel('Improvement (%)')
    plt.title('RL Improvement Over PUSH System')
    
    for i, v in enumerate(improvements.values()):
        plt.text(i, v + (1 if v > 0 else -3), f"{v:.1f}%", ha='center')
    
    plt.tight_layout()
    plt.show()
    
    print("\nPerformance Summary:")
    print(f"{'Metric':<35} {'PUSH':<10} {'RL':<10} {'Improvement':<10}")
    print("-" * 70)
    for m in metrics:
        print(f"{m:<35} {push_means[m]:<10.4f} {rl_means[m]:<10.4f} {improvements[m]:<10.1f}%")
    
    return improvements

final_improvements = compare_results(push_results, optimized_results)
# Out:
# Performance Summary:
# Metric                              PUSH       RL         Improvement
# ----------------------------------------------------------------------
# Average jobs in system (L)          32.4120    28.4225    12.3      %
# Average Total Remaining Workload    142.8513   136.5587   4.4       %
# Average Tardiness                   19.0852    131.7360   -590.3    %
# Throughput                          0.6451     0.6434     -0.3      %
# Jobs Completed                      12908.8000 12822.8000 -0.7      %
# Average Flow Times                  50.2815    171.7601   -241.6    %

# %%
# Confidence Interval Calculation for RL Agent System
import scipy.stats as stats

def run_rl_replication():
    """Run one replication of the RL agent simulation and return KPIs"""
    # Create a single environment instance
    env = ManufacturingEnv()

    # Load the normalization stats and wrap the environment
    norm_env = VecNormalize.load("optimized_vec_normalize.pkl", DummyVecEnv([lambda: ManufacturingEnv()]))
    norm_env.training = False
    norm_env.norm_reward = False

    # Load the trained model
    model = PPO.load("optimized_production_agent", env=norm_env, device='cpu')
    state = env.reset()
    done = False
    while not done:
        action, _ = model.predict(state, deterministic=True)
        state, _, done, _ = env.step(action)
    kpis = env.get_kpis()
    return {
        'Average jobs in system (L)': kpis['Average jobs in system (L)'],
        'Average Total Remaining Workload': kpis['Average Total Remaining Workload'],
        'Average Tardiness': kpis['Average Tardiness'],
        'Average Earliness': kpis['Average Earliness'],
        'Throughput': kpis['Throughput']
    }

def compute_confidence_intervals(metrics, alpha=0.05, gamma=0.05, n0=5):
    """
    Compute confidence intervals using sequential procedure
    metrics: list of metric names to analyze
    alpha: significance level (1-alpha confidence interval)
    gamma: relative error threshold
    n0: initial number of replications
    max_reps: maximum number of replications to prevent infinite loops
    """
    data = {metric: [] for metric in metrics}
    n = n0
    
    # Initial replications
    print(f"Running initial {n0} replications...")
    for _ in range(n0):
        rep_data = run_rl_replication()
        for metric in metrics:
            data[metric].append(rep_data[metric])
    
    # Sequential procedure
    while True:
        print(f"\n--- n = {n} ---")
        all_metrics_meet_criteria = True
        results = {}
        
        for metric in metrics:
            values = np.array(data[metric])
            mean = np.mean(values)
            var = np.var(values, ddof=1)  # Sample variance
            
            # Handle case where variance is zero
            if var == 0:
                std_err = 0
                delta = 0
            else:
                std_err = np.sqrt(var / n)
                t_val = stats.t.ppf(1 - alpha/2, n-1)
                delta = t_val * std_err
            
            # Relative error check (handle near-zero means)
            if abs(mean) < 0.1:  # Avoid division by zero
                meets_criteria = delta < 0.01  # Absolute threshold for near-zero means
            else:
                meets_criteria = (delta / abs(mean)) <= gamma
            
            results[metric] = {
                'mean': mean,
                'variance': var,
                'delta': delta,
                'meets_criteria': meets_criteria
            }
            
            print(f"{metric}:")
            print(f"  Mean = {mean:.4f}, Var = {var:.4f}, Δ = {delta:.4f}")
            print(f"  Relative error = {delta/abs(mean):.4f} (Criteria met: {meets_criteria})")
            
            if not meets_criteria:
                all_metrics_meet_criteria = False
        
        # Check if all metrics meet the criteria
        if all_metrics_meet_criteria:
            print("\nAll metrics meet the relative error criteria!")
            final_results = {}
            for metric in metrics:
                final_results[metric] = {
                    'point_estimate': results[metric]['mean'],
                    'ci_lower': results[metric]['mean'] - results[metric]['delta'],
                    'ci_upper': results[metric]['mean'] + results[metric]['delta'],
                    'n': n
                }
            return final_results
        
        # Run additional replication if needed
        n += 1
        print(f"\nRunning additional replication (n = {n})...")
        rep_data = run_rl_replication()
        for metric in metrics:
            data[metric].append(rep_data[metric])

# Compute confidence intervals
metrics_to_analyze = ['Average jobs in system (L)', 'Average Total Remaining Workload', 'Average Tardiness', 'Average Earliness', 'Throughput']
confidence_intervals = compute_confidence_intervals(metrics_to_analyze)

# Display results
if confidence_intervals:
    print("\n\n=== Final Confidence Intervals ===")
    print(f"{'Metric':<35} {'Point Estimate':<15} {'95% CI':<25} {'Replications'}")
    print("-" * 70)
    for metric, ci in confidence_intervals.items():
        point_est = ci['point_estimate']
        ci_str = f"[{ci['ci_lower']:.4f}, {ci['ci_upper']:.4f}]"
        print(f"{metric:<35} {point_est:<15.4f} {ci_str:<25} {ci['n']}")
else:
    print("Failed to compute confidence intervals")
# Out:
# Running initial 5 replications...
# /home/matteo/anaconda3/envs/unimore_aai/lib/python3.13/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# --- n = 5 ---
# Average jobs in system (L):
#   Mean = 28.1152, Var = 12.4265, Δ = 4.3770
#   Relative error = 0.1557 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 139.2125, Var = 144.3430, Δ = 14.9177
#   Relative error = 0.1072 (Criteria met: False)
# Average Tardiness:
#   Mean = 127.4123, Var = 63.7337, Δ = 9.9126
#   Relative error = 0.0778 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6464, Var = 0.0001, Δ = 0.0095
#   Relative error = 0.0147 (Criteria met: True)
#
# Running additional replication (n = 6)...
# /tmp/ipykernel_1797081/3968935674.py:84: RuntimeWarning: invalid value encountered in scalar divide
#   print(f"  Relative error = {delta/abs(mean):.4f} (Criteria met: {meets_criteria})")
# --- n = 6 ---
# Average jobs in system (L):
#   Mean = 29.8630, Var = 28.2693, Δ = 5.5797
#   Relative error = 0.1868 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.0646, Var = 320.9587, Δ = 18.8010
#   Relative error = 0.1296 (Criteria met: False)
# Average Tardiness:
#   Mean = 134.7284, Var = 372.1354, Δ = 20.2445
#   Relative error = 0.1503 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6478, Var = 0.0001, Δ = 0.0080
#   Relative error = 0.0124 (Criteria met: True)
#
# Running additional replication (n = 7)...
#
# --- n = 7 ---
# Average jobs in system (L):
#   Mean = 29.4178, Var = 24.9450, Δ = 4.6191
#   Relative error = 0.1570 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.8507, Var = 301.7763, Δ = 16.0662
#   Relative error = 0.1125 (Criteria met: False)
# Average Tardiness:
#   Mean = 132.4826, Var = 345.4178, Δ = 17.1886
#   Relative error = 0.1297 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6463, Var = 0.0001, Δ = 0.0073
#   Relative error = 0.0113 (Criteria met: True)
#
# Running additional replication (n = 8)...
#
# --- n = 8 ---
# Average jobs in system (L):
#   Mean = 30.0842, Var = 24.9345, Δ = 4.1746
#   Relative error = 0.1388 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.2550, Var = 304.9104, Δ = 14.5983
#   Relative error = 0.1005 (Criteria met: False)
# Average Tardiness:
#   Mean = 133.7088, Var = 308.1008, Δ = 14.6745
#   Relative error = 0.1097 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6466, Var = 0.0001, Δ = 0.0061
#   Relative error = 0.0095 (Criteria met: True)
#
# Running additional replication (n = 9)...
#
# --- n = 9 ---
# Average jobs in system (L):
#   Mean = 29.9527, Var = 21.9732, Δ = 3.6032
#   Relative error = 0.1203 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.8272, Var = 268.4434, Δ = 12.5940
#   Relative error = 0.0870 (Criteria met: False)
# Average Tardiness:
#   Mean = 133.3662, Var = 270.6444, Δ = 12.6456
#   Relative error = 0.0948 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6464, Var = 0.0000, Δ = 0.0053
#   Relative error = 0.0082 (Criteria met: True)
#
# Running additional replication (n = 10)...
#
# --- n = 10 ---
# Average jobs in system (L):
#   Mean = 29.4012, Var = 22.5734, Δ = 3.3988
#   Relative error = 0.1156 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 143.1937, Var = 265.3012, Δ = 11.6518
#   Relative error = 0.0814 (Criteria met: False)
# Average Tardiness:
#   Mean = 131.3037, Var = 283.1134, Δ = 12.0366
#   Relative error = 0.0917 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6460, Var = 0.0000, Δ = 0.0047
#   Relative error = 0.0073 (Criteria met: True)
#
# Running additional replication (n = 11)...
#
# --- n = 11 ---
# Average jobs in system (L):
#   Mean = 29.0394, Var = 21.7566, Δ = 3.1336
#   Relative error = 0.1079 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 141.9598, Var = 255.5191, Δ = 10.7388
#   Relative error = 0.0756 (Criteria met: False)
# Average Tardiness:
#   Mean = 129.0968, Var = 308.3782, Δ = 11.7974
#   Relative error = 0.0914 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6459, Var = 0.0000, Δ = 0.0042
#   Relative error = 0.0066 (Criteria met: True)
#
# Running additional replication (n = 12)...
#
# --- n = 12 ---
# Average jobs in system (L):
#   Mean = 29.0904, Var = 19.8100, Δ = 2.8279
#   Relative error = 0.0972 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.5343, Var = 236.2513, Δ = 9.7659
#   Relative error = 0.0685 (Criteria met: False)
# Average Tardiness:
#   Mean = 129.4807, Var = 282.1129, Δ = 10.6718
#   Relative error = 0.0824 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6461, Var = 0.0000, Δ = 0.0038
#   Relative error = 0.0060 (Criteria met: True)
#
# Running additional replication (n = 13)...
#
# --- n = 13 ---
# Average jobs in system (L):
#   Mean = 29.5716, Var = 21.1688, Δ = 2.7803
#   Relative error = 0.0940 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 143.3261, Var = 224.7132, Δ = 9.0586
#   Relative error = 0.0632 (Criteria met: False)
# Average Tardiness:
#   Mean = 130.0131, Var = 262.2875, Δ = 9.7867
#   Relative error = 0.0753 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6461, Var = 0.0000, Δ = 0.0035
#   Relative error = 0.0054 (Criteria met: True)
#
# Running additional replication (n = 14)...
#
# --- n = 14 ---
# Average jobs in system (L):
#   Mean = 29.2872, Var = 20.6726, Δ = 2.6252
#   Relative error = 0.0896 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.6473, Var = 213.8784, Δ = 8.4440
#   Relative error = 0.0592 (Criteria met: False)
# Average Tardiness:
#   Mean = 128.5825, Var = 270.7634, Δ = 9.5008
#   Relative error = 0.0739 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6465, Var = 0.0000, Δ = 0.0033
#   Relative error = 0.0051 (Criteria met: True)
#
# Running additional replication (n = 15)...
#
# --- n = 15 ---
# Average jobs in system (L):
#   Mean = 29.5805, Var = 20.4858, Δ = 2.5065
#   Relative error = 0.0847 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 143.3603, Var = 206.2278, Δ = 7.9527
#   Relative error = 0.0555 (Criteria met: False)
# Average Tardiness:
#   Mean = 129.6220, Var = 267.6331, Δ = 9.0596
#   Relative error = 0.0699 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6463, Var = 0.0000, Δ = 0.0031
#   Relative error = 0.0048 (Criteria met: True)
#
# Running additional replication (n = 16)...
#
# --- n = 16 ---
# Average jobs in system (L):
#   Mean = 29.5183, Var = 19.1818, Δ = 2.3338
#   Relative error = 0.0791 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.9812, Var = 194.7786, Δ = 7.4368
#   Relative error = 0.0520 (Criteria met: False)
# Average Tardiness:
#   Mean = 128.9103, Var = 257.8946, Δ = 8.5573
#   Relative error = 0.0664 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6463, Var = 0.0000, Δ = 0.0029
#   Relative error = 0.0044 (Criteria met: True)
#
# Running additional replication (n = 17)...
#
# --- n = 17 ---
# Average jobs in system (L):
#   Mean = 29.3803, Var = 18.3067, Δ = 2.1999
#   Relative error = 0.0749 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.6988, Var = 183.9607, Δ = 6.9736
#   Relative error = 0.0489 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.7320, Var = 242.3170, Δ = 8.0036
#   Relative error = 0.0622 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6464, Var = 0.0000, Δ = 0.0027
#   Relative error = 0.0042 (Criteria met: True)
#
# Running additional replication (n = 18)...
#
# --- n = 18 ---
# Average jobs in system (L):
#   Mean = 29.2160, Var = 17.7161, Δ = 2.0931
#   Relative error = 0.0716 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.2002, Var = 177.6150, Δ = 6.6275
#   Relative error = 0.0466 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.8618, Var = 241.6929, Δ = 7.7311
#   Relative error = 0.0605 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6465, Var = 0.0000, Δ = 0.0025
#   Relative error = 0.0039 (Criteria met: True)
#
# Running additional replication (n = 19)...
#
# --- n = 19 ---
# Average jobs in system (L):
#   Mean = 28.8188, Var = 19.7298, Δ = 2.1409
#   Relative error = 0.0743 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 140.7389, Var = 208.3212, Δ = 6.9566
#   Relative error = 0.0494 (Criteria met: True)
# Average Tardiness:
#   Mean = 126.9636, Var = 243.5937, Δ = 7.5226
#   Relative error = 0.0592 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6460, Var = 0.0000, Δ = 0.0026
#   Relative error = 0.0040 (Criteria met: True)
#
# Running additional replication (n = 20)...
#
# --- n = 20 ---
# Average jobs in system (L):
#   Mean = 28.8011, Var = 18.6976, Δ = 2.0237
#   Relative error = 0.0703 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 140.7365, Var = 197.3571, Δ = 6.5748
#   Relative error = 0.0467 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.0969, Var = 231.1284, Δ = 7.1152
#   Relative error = 0.0560 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6460, Var = 0.0000, Δ = 0.0024
#   Relative error = 0.0038 (Criteria met: True)
#
# Running additional replication (n = 21)...
#
# --- n = 21 ---
# Average jobs in system (L):
#   Mean = 28.9043, Var = 17.9864, Δ = 1.9305
#   Relative error = 0.0668 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 141.0167, Var = 189.1385, Δ = 6.2602
#   Relative error = 0.0444 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.3175, Var = 220.5938, Δ = 6.7607
#   Relative error = 0.0531 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6461, Var = 0.0000, Δ = 0.0023
#   Relative error = 0.0036 (Criteria met: True)
#
# Running additional replication (n = 22)...
#
# --- n = 22 ---
# Average jobs in system (L):
#   Mean = 28.6234, Var = 18.8658, Δ = 1.9258
#   Relative error = 0.0673 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 139.9112, Var = 207.0193, Δ = 6.3794
#   Relative error = 0.0456 (Criteria met: True)
# Average Tardiness:
#   Mean = 126.5147, Var = 224.2664, Δ = 6.6398
#   Relative error = 0.0525 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6458, Var = 0.0000, Δ = 0.0023
#   Relative error = 0.0036 (Criteria met: True)
#
# Running additional replication (n = 23)...
#
# --- n = 23 ---
# Average jobs in system (L):
#   Mean = 28.6497, Var = 18.0242, Δ = 1.8359
#   Relative error = 0.0641 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 140.2391, Var = 200.0818, Δ = 6.1168
#   Relative error = 0.0436 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.0012, Var = 219.5143, Δ = 6.4069
#   Relative error = 0.0504 (Criteria met: False)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6456, Var = 0.0000, Δ = 0.0022
#   Relative error = 0.0034 (Criteria met: True)
#
# Running additional replication (n = 24)...
#
# --- n = 24 ---
# Average jobs in system (L):
#   Mean = 28.6362, Var = 17.2448, Δ = 1.7535
#   Relative error = 0.0612 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 140.2909, Var = 191.4470, Δ = 5.8426
#   Relative error = 0.0416 (Criteria met: True)
# Average Tardiness:
#   Mean = 126.6056, Var = 213.7248, Δ = 6.1732
#   Relative error = 0.0488 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6458, Var = 0.0000, Δ = 0.0022
#   Relative error = 0.0033 (Criteria met: True)
#
# Running additional replication (n = 25)...
#
# --- n = 25 ---
# Average jobs in system (L):
#   Mean = 28.9797, Var = 19.4757, Δ = 1.8217
#   Relative error = 0.0629 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 141.2440, Var = 206.1846, Δ = 5.9272
#   Relative error = 0.0420 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.4777, Var = 223.8311, Δ = 6.1756
#   Relative error = 0.0484 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6462, Var = 0.0000, Δ = 0.0022
#   Relative error = 0.0034 (Criteria met: True)
#
# Running additional replication (n = 26)...
#
# --- n = 26 ---
# Average jobs in system (L):
#   Mean = 29.0920, Var = 19.0245, Δ = 1.7617
#   Relative error = 0.0606 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 141.7915, Var = 205.7301, Δ = 5.7934
#   Relative error = 0.0409 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.7201, Var = 216.4058, Δ = 5.9418
#   Relative error = 0.0465 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6463, Var = 0.0000, Δ = 0.0021
#   Relative error = 0.0033 (Criteria met: True)
#
# Running additional replication (n = 27)...
#
# --- n = 27 ---
# Average jobs in system (L):
#   Mean = 29.1402, Var = 18.3554, Δ = 1.6948
#   Relative error = 0.0582 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 141.8752, Var = 198.0067, Δ = 5.5665
#   Relative error = 0.0392 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.9791, Var = 209.8943, Δ = 5.7312
#   Relative error = 0.0448 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6465, Var = 0.0000, Δ = 0.0021
#   Relative error = 0.0032 (Criteria met: True)
#
# Running additional replication (n = 28)...
#
# --- n = 28 ---
# Average jobs in system (L):
#   Mean = 29.1480, Var = 17.6773, Δ = 1.6303
#   Relative error = 0.0559 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.1209, Var = 192.3627, Δ = 5.3780
#   Relative error = 0.0378 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.6145, Var = 205.8424, Δ = 5.5633
#   Relative error = 0.0436 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6465, Var = 0.0000, Δ = 0.0020
#   Relative error = 0.0031 (Criteria met: True)
#
# Running additional replication (n = 29)...
#
# --- n = 29 ---
# Average jobs in system (L):
#   Mean = 29.3624, Var = 18.3794, Δ = 1.6307
#   Relative error = 0.0555 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.6860, Var = 194.7528, Δ = 5.3083
#   Relative error = 0.0372 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.1295, Var = 206.1812, Δ = 5.4619
#   Relative error = 0.0426 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6467, Var = 0.0000, Δ = 0.0019
#   Relative error = 0.0030 (Criteria met: True)
#
# Running additional replication (n = 30)...
#
# --- n = 30 ---
# Average jobs in system (L):
#   Mean = 29.4087, Var = 17.8098, Δ = 1.5758
#   Relative error = 0.0536 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.9126, Var = 189.5774, Δ = 5.1413
#   Relative error = 0.0360 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.8363, Var = 201.6503, Δ = 5.3025
#   Relative error = 0.0415 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6468, Var = 0.0000, Δ = 0.0019
#   Relative error = 0.0029 (Criteria met: True)
#
# Running additional replication (n = 31)...
#
# --- n = 31 ---
# Average jobs in system (L):
#   Mean = 29.2408, Var = 18.0903, Δ = 1.5601
#   Relative error = 0.0534 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 142.2321, Var = 197.6109, Δ = 5.1563
#   Relative error = 0.0363 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.5627, Var = 197.2494, Δ = 5.1516
#   Relative error = 0.0404 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6464, Var = 0.0000, Δ = 0.0020
#   Relative error = 0.0030 (Criteria met: True)
#
# Running additional replication (n = 32)...
#
# --- n = 32 ---
# Average jobs in system (L):
#   Mean = 29.6489, Var = 22.8363, Δ = 1.7229
#   Relative error = 0.0581 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 143.1879, Var = 220.4707, Δ = 5.3534
#   Relative error = 0.0374 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.4074, Var = 213.7194, Δ = 5.2708
#   Relative error = 0.0410 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6466, Var = 0.0000, Δ = 0.0019
#   Relative error = 0.0030 (Criteria met: True)
#
# Running additional replication (n = 33)...
#
# --- n = 33 ---
# Average jobs in system (L):
#   Mean = 29.9648, Var = 25.4161, Δ = 1.7876
#   Relative error = 0.0597 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.4270, Var = 264.2490, Δ = 5.7640
#   Relative error = 0.0399 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.8006, Var = 212.1434, Δ = 5.1646
#   Relative error = 0.0401 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6471, Var = 0.0000, Δ = 0.0021
#   Relative error = 0.0032 (Criteria met: True)
#
# Running additional replication (n = 34)...
#
# --- n = 34 ---
# Average jobs in system (L):
#   Mean = 29.9790, Var = 24.6527, Δ = 1.7324
#   Relative error = 0.0578 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.6433, Var = 257.8314, Δ = 5.6026
#   Relative error = 0.0387 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.4079, Var = 210.9581, Δ = 5.0678
#   Relative error = 0.0395 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6474, Var = 0.0000, Δ = 0.0021
#   Relative error = 0.0033 (Criteria met: True)
#
# Running additional replication (n = 35)...
#
# --- n = 35 ---
# Average jobs in system (L):
#   Mean = 29.8040, Var = 24.9994, Δ = 1.7175
#   Relative error = 0.0576 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.1063, Var = 260.3406, Δ = 5.5426
#   Relative error = 0.0385 (Criteria met: True)
# Average Tardiness:
#   Mean = 127.7619, Var = 219.3591, Δ = 5.0877
#   Relative error = 0.0398 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6473, Var = 0.0000, Δ = 0.0021
#   Relative error = 0.0032 (Criteria met: True)
#
# Running additional replication (n = 36)...
#
# --- n = 36 ---
# Average jobs in system (L):
#   Mean = 29.9535, Var = 25.0905, Δ = 1.6948
#   Relative error = 0.0566 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.8305, Var = 271.7845, Δ = 5.5780
#   Relative error = 0.0385 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.4119, Var = 228.3019, Δ = 5.1124
#   Relative error = 0.0398 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6475, Var = 0.0000, Δ = 0.0020
#   Relative error = 0.0031 (Criteria met: True)
#
# Running additional replication (n = 37)...
#
# --- n = 37 ---
# Average jobs in system (L):
#   Mean = 30.2670, Var = 28.0300, Δ = 1.7652
#   Relative error = 0.0583 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.8877, Var = 305.5884, Δ = 5.8285
#   Relative error = 0.0400 (Criteria met: True)
# Average Tardiness:
#   Mean = 129.0080, Var = 235.1063, Δ = 5.1123
#   Relative error = 0.0396 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6477, Var = 0.0000, Δ = 0.0020
#   Relative error = 0.0031 (Criteria met: True)
#
# Running additional replication (n = 38)...
#
# --- n = 38 ---
# Average jobs in system (L):
#   Mean = 30.0220, Var = 29.5534, Δ = 1.7869
#   Relative error = 0.0595 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.0019, Var = 327.1496, Δ = 5.9451
#   Relative error = 0.0410 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.9637, Var = 228.8267, Δ = 4.9721
#   Relative error = 0.0386 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6474, Var = 0.0000, Δ = 0.0021
#   Relative error = 0.0033 (Criteria met: True)
#
# Running additional replication (n = 39)...
#
# --- n = 39 ---
# Average jobs in system (L):
#   Mean = 30.1680, Var = 29.6066, Δ = 1.7638
#   Relative error = 0.0585 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.3333, Var = 322.8238, Δ = 5.8243
#   Relative error = 0.0401 (Criteria met: True)
# Average Tardiness:
#   Mean = 129.2519, Var = 226.0447, Δ = 4.8737
#   Relative error = 0.0377 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6474, Var = 0.0000, Δ = 0.0021
#   Relative error = 0.0032 (Criteria met: True)
#
# Running additional replication (n = 40)...
#
# --- n = 40 ---
# Average jobs in system (L):
#   Mean = 30.2085, Var = 28.9130, Δ = 1.7197
#   Relative error = 0.0569 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.6419, Var = 318.3555, Δ = 5.7063
#   Relative error = 0.0392 (Criteria met: True)
# Average Tardiness:
#   Mean = 129.0871, Var = 221.3360, Δ = 4.7580
#   Relative error = 0.0369 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6473, Var = 0.0000, Δ = 0.0020
#   Relative error = 0.0031 (Criteria met: True)
#
# Running additional replication (n = 41)...
#
# --- n = 41 ---
# Average jobs in system (L):
#   Mean = 30.0654, Var = 29.0293, Δ = 1.7006
#   Relative error = 0.0566 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.2287, Var = 317.3966, Δ = 5.6233
#   Relative error = 0.0387 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.6406, Var = 223.9734, Δ = 4.7238
#   Relative error = 0.0367 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6473, Var = 0.0000, Δ = 0.0020
#   Relative error = 0.0030 (Criteria met: True)
#
# Running additional replication (n = 42)...
#
# --- n = 42 ---
# Average jobs in system (L):
#   Mean = 30.0000, Var = 28.5010, Δ = 1.6636
#   Relative error = 0.0555 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.9139, Var = 313.8162, Δ = 5.5203
#   Relative error = 0.0381 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.5180, Var = 219.1426, Δ = 4.6131
#   Relative error = 0.0359 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6471, Var = 0.0000, Δ = 0.0019
#   Relative error = 0.0030 (Criteria met: True)
#
# Running additional replication (n = 43)...
#
# --- n = 43 ---
# Average jobs in system (L):
#   Mean = 29.9281, Var = 28.0447, Δ = 1.6298
#   Relative error = 0.0545 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.7844, Var = 307.0659, Δ = 5.3929
#   Relative error = 0.0372 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.2610, Var = 216.7647, Δ = 4.5310
#   Relative error = 0.0353 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6470, Var = 0.0000, Δ = 0.0019
#   Relative error = 0.0029 (Criteria met: True)
#
# Running additional replication (n = 44)...
#
# --- n = 44 ---
# Average jobs in system (L):
#   Mean = 29.9580, Var = 27.4318, Δ = 1.5924
#   Relative error = 0.0532 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.7471, Var = 299.9858, Δ = 5.2658
#   Relative error = 0.0364 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.4488, Var = 213.2750, Δ = 4.4400
#   Relative error = 0.0346 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6470, Var = 0.0000, Δ = 0.0019
#   Relative error = 0.0029 (Criteria met: True)
#
# Running additional replication (n = 45)...
#
# --- n = 45 ---
# Average jobs in system (L):
#   Mean = 29.9545, Var = 26.8089, Δ = 1.5556
#   Relative error = 0.0519 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 144.8860, Var = 294.0359, Δ = 5.1517
#   Relative error = 0.0356 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.3969, Var = 208.5490, Δ = 4.3386
#   Relative error = 0.0338 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6470, Var = 0.0000, Δ = 0.0018
#   Relative error = 0.0028 (Criteria met: True)
#
# Running additional replication (n = 46)...
#
# --- n = 46 ---
# Average jobs in system (L):
#   Mean = 30.0390, Var = 26.5423, Δ = 1.5299
#   Relative error = 0.0509 (Criteria met: False)
# Average Total Remaining Workload:
#   Mean = 145.1062, Var = 289.7312, Δ = 5.0548
#   Relative error = 0.0348 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.9452, Var = 217.7451, Δ = 4.3820
#   Relative error = 0.0340 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6471, Var = 0.0000, Δ = 0.0018
#   Relative error = 0.0027 (Criteria met: True)
#
# Running additional replication (n = 47)...
#
# --- n = 47 ---
# Average jobs in system (L):
#   Mean = 30.0518, Var = 25.9730, Δ = 1.4964
#   Relative error = 0.0498 (Criteria met: True)
# Average Total Remaining Workload:
#   Mean = 145.1684, Var = 283.6147, Δ = 4.9447
#   Relative error = 0.0341 (Criteria met: True)
# Average Tardiness:
#   Mean = 128.8226, Var = 213.7183, Δ = 4.2923
#   Relative error = 0.0333 (Criteria met: True)
# Average Earliness:
#   Mean = 0.0000, Var = 0.0000, Δ = 0.0000
#   Relative error = nan (Criteria met: True)
# Throughput:
#   Mean = 0.6471, Var = 0.0000, Δ = 0.0017
#   Relative error = 0.0027 (Criteria met: True)
#
# All metrics meet the relative error criteria!
#
#
# === Final Confidence Intervals ===
# Metric                              Point Estimate  95% CI                    Replications
# ----------------------------------------------------------------------
# Average jobs in system (L)          30.0518         [28.5555, 31.5482]        47
# Average Total Remaining Workload    145.1684        [140.2237, 150.1131]      47
# Average Tardiness                   128.8226        [124.5302, 133.1149]      47
# Average Earliness                   0.0000          [0.0000, 0.0000]          47
# Throughput                          0.6471          [0.6454, 0.6488]          47

# %%
def run_simulation():
    # Create a single environment instance
    env = ManufacturingEnv()

    # Load the normalization stats and wrap the environment
    norm_env = VecNormalize.load("optimized_vec_normalize.pkl", DummyVecEnv([lambda: ManufacturingEnv()]))
    norm_env.training = False
    norm_env.norm_reward = False

    # Load the trained model
    model = PPO.load("optimized_production_agent", env=norm_env, device='cpu')
    state = env.reset()
    done = False
    while not done:
        action, _ = model.predict(state, deterministic=True)
        state, _, done, _ = env.step(action)

    return env.stats, env.get_kpis()

def moving_average(data, window_size=100):
    """Calculate moving average with specified window size"""
    if len(data) < window_size:
        return data
    
    window = np.ones(window_size) / window_size
    return np.convolve(data, window, mode='valid')

def graphs(stats, kpis):
    plt.figure(figsize=(15, 15))

    # Total Remaining Workload over time
    plt.subplot(3, 2, 1)
    if stats['workload_events']:
        # Sort events by time
        events = sorted(stats['workload_events'], key=lambda x: x[0])
        times, workloads = zip(*events)
        
        # Create step plot for raw workload
        plt.step(times, workloads, where='post', color='m', alpha=0.3, label='Raw Workload')
        
        # Calculate and plot moving average
        window_size = 500  # Adjust this to control smoothness
        if len(workloads) > window_size:
            smoothed = moving_average(workloads, window_size)
            # Adjust times to match smoothed data length
            plt.plot(times[window_size-1:], smoothed, 'b-', linewidth=1.5, 
                    label=f'Moving Average (window={window_size})')
        
        plt.axvline(WARM_UP, color='r', linestyle='--', label='Warm-up end')
        plt.axhline(kpis['Average Total Remaining Workload'], color='darkmagenta', 
                   linestyle='--', label=f'Avg: {kpis["Average Total Remaining Workload"]:.2f}')
        plt.title('Total Remaining Workload Over Time')
        plt.xlabel('Simulation Time')
        plt.ylabel('Workload')
        plt.legend()
        plt.grid(True, alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'No workload data available', 
                 ha='center', va='center', fontsize=12)
        plt.title('Total Remaining Workload Over Time')

    # Flow time graph
    plt.subplot(4, 2, 2)
    if stats['flow_times']:
        # Sort events by time
        events = sorted(stats['flow_times'], key=lambda x: x[0])
        times, flow_times = zip(*events)
        
        # Create step plot for raw flow_times
        plt.step(times, flow_times, where='post', color='m', alpha=0.3, label='Raw Flow Times')
        
        # Calculate and plot moving average
        window_size = 500  # Adjust this to control smoothness
        if len(flow_times) > window_size:
            smoothed = moving_average(flow_times, window_size)
            # Adjust times to match smoothed data length
            plt.plot(times[window_size-1:], smoothed, 'b-', linewidth=1.5, 
                    label=f'Moving Average (window={window_size})')
        
        plt.axvline(WARM_UP, color='r', linestyle='--', label='Warm-up end')
        plt.axhline(kpis['Average Flow Times'], color='darkmagenta', 
                   linestyle='--', label=f'Avg: {kpis["Average Flow Times"]:.2f}')
        plt.title('Flow Times (Per Job Completion)')
        plt.xlabel('Simulation Time')
        plt.ylabel('Flow Times')
        plt.legend()
        plt.grid(True, alpha=0.3)
    else:
        plt.text(0.5, 0.5, 'No flow_times data available', 
                 ha='center', va='center', fontsize=12)
        plt.title('Flow Times (Per Job Completion)')

    # plot tardiness over time
    plt.subplot(3,2,3)

    if not stats['tardiness_over_time']:
        plt.text(0.5, 0.5, 'No tardiness data available', 
                    ha='center', va='center', fontsize=16)
        plt.title('Tardiness Evolution Over Time')
        return

    # Extract and sort data
    times, tardiness = zip(*stats['tardiness_over_time'])
    sorted_idx = np.argsort(times)
    times = np.array(times)[sorted_idx]
    tardiness = np.array(tardiness)[sorted_idx]

    # Calculate cumulative average
    cum_avg = np.cumsum(tardiness) / (np.arange(len(tardiness)) + 1)

    # Create plot
    plt.scatter(times, tardiness, alpha=0.3, color='salmon', 
                label='Individual Job Tardiness')
    plt.plot(times, cum_avg, 'b-', linewidth=2.5, 
                label='Cumulative Average Tardiness')

    plt.axvline(WARM_UP, color='r', linestyle='--', alpha=0.7, label='Warm-up end')
    plt.title('Tardiness Evolution Over Time')
    plt.xlabel('Simulation Time')
    plt.ylabel('Tardiness')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # plot earliness over time
    plt.subplot(3,2,4)

    if not stats['earliness_over_time']:
        plt.text(0.5, 0.5, 'No earliness data available', 
                ha='center', va='center', fontsize=16)
        plt.title('Earliness Evolution Over Time')
        return

    # Extract and sort data
    times, earliness = zip(*stats['earliness_over_time'])
    sorted_idx = np.argsort(times)
    times = np.array(times)[sorted_idx]
    earliness = np.array(earliness)[sorted_idx]

    # Calculate cumulative average
    cum_avg = np.cumsum(earliness) / (np.arange(len(earliness)) + 1)

    # Create plot
    plt.scatter(times, earliness, alpha=0.3, color='lightgreen', 
                label='Individual Job Earliness')
    plt.plot(times, cum_avg, 'g-', linewidth=2.5, 
            label='Cumulative Average Earliness')

    plt.axvline(WARM_UP, color='r', linestyle='--', alpha=0.7, label='Warm-up end')
    plt.title('Earliness Evolution Over Time')
    plt.xlabel('Simulation Time')
    plt.ylabel('Earliness')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Family tardiness
    plt.subplot(3,2,5)
    family_tardiness = [
        stats['family_tardiness'][1],
        stats['family_tardiness'][2],
        stats['family_tardiness'][3]
    ]
    plt.boxplot(family_tardiness, 
                   tick_labels=['Family 1', 'Family 2', 'Family 3'])
    plt.title('Tardiness by Product Family')
    plt.ylabel('Tardiness')
    
    # Family earliness
    plt.subplot(3,2,6)
    family_earliness = [
        stats['family_earliness'][1],
        stats['family_earliness'][2],
        stats['family_earliness'][3]
    ]
    plt.boxplot(family_earliness, 
                   tick_labels=['Family 1', 'Family 2', 'Family 3'])
    plt.title('Earliness by Product Family')
    plt.ylabel('Earliness')

    plt.show()

stats, kpis = run_simulation()
graphs(stats, kpis)
